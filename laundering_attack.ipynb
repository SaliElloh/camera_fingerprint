# %%
import os
# Out:
# Running cells with 'Python 3.11.11' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.11 -m pip install ipykernel -U --user --force-reinstall'

# %%
test_img_dir = '/scratch/hafiz_root/hafiz1/shared_data/Data/test_dataset'
# Out:
# Running cells with 'Python 3.11.11' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.11 -m pip install ipykernel -U --user --force-reinstall'

# %%
camera_lst = os.listdir(test_img_dir)
# Out:
# Running cells with 'Python 3.11.11' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.11 -m pip install ipykernel -U --user --force-reinstall'
